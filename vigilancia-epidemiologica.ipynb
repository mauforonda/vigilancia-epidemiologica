# %% [markdown]
# # Vigilancia epidemiológica

# %% [markdown]
# Cada mes, cientos de establecimientos de salud en Bolivia envían información sobre la prevalencia de enfermedades que el Estado considera de relevancia epidemiológica. Esta información es consolidada y presentada en [tableros](https://estadisticas.minsalud.gob.bo/Default_Vigilancia.aspx) que creo podrían ser mucho más amigables de usar. Hay tantos usos como visualizaciones, modelos de proyección o simples índices de incidencia, que en el estado actual serían demasiado tediosos de producir. Por eso, en este trabajo produzco una forma reproducible y escalable de descargar todos estos datos a nivel municipal y mensual para cada condición registrada y año entre 2001 y 2021.

# %%
# dependencias

import pandas as pd
import requests
import datetime as dt
from bs4 import BeautifulSoup
import unicodedata
from slugify import slugify
from IPython.display import clear_output
from itables import show, init_notebook_mode
init_notebook_mode()
from IPython.display import display, IFrame
import itertools
import re
import json

# %% [markdown]
# Antes que nada, los datos. En este tablero puedes explorar algunas vistas interesantes:

# %%
display(IFrame(src='https://observablehq.com/embed/@mauforonda/vigilancia-epidemiologica/2?cells=barplot%2Ctext1%2Cviewof+nombre%2Cviewof+column%2Cheading1%2Clegend%2Cviewof+munselect%2Cheading2%2Clineplot%2Ctabla%2Ctext2%2Ctext3', width="100%", height="2500"))
# Out:
#         <iframe
#             width="100%"
#             height="2500"
#             src="https://observablehq.com/embed/@mauforonda/vigilancia-epidemiologica/2?cells=barplot%2Ctext1%2Cviewof+nombre%2Cviewof+column%2Cheading1%2Clegend%2Cviewof+munselect%2Cheading2%2Clineplot%2Ctabla%2Ctext2%2Ctext3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Esta tabla muestra los datos para casos clasificados en una variable y año, con enlaces a documentos csv:

# %%
def draw_table(df):
    
    def link(dfi, name, link):
        return dfi[[link, name]].apply(lambda row: '<a href="{}">{}</a>'.format(row[0], row[1]), axis=1)
    
    dfi = df.copy()
    url_base = 'https://mauforonda.github.io/vigilancia-epidemiologica/datos/'
    dfi['filename'] = dfi.filename.apply(lambda f: '{}{}'.format(url_base, f))
    dfi['variable'] = link(dfi, name='variable', link='filename')
    dfi = dfi[['year', 'grupo', 'variable']]
    dfi.columns = ['Año', 'Grupo', 'Variable']
    
    show(dfi, 
         order = [],
         hover = True,
         compact=True,
         scrollY="900px", 
         lengthMenu=[50,100],
         scrollCollapse=True,
         search={"caseInsensitive": True},
         paging=True,
         language={
             'lengthMenu': 'Mostrar _MENU_ filas',
             'search': '&#x1F50E;&#xFE0E;', 
             'processing': 'creando tabla ...', 
             'info': '', 
             'infoEmpty': '', 
             'infoFiltered':'_TOTAL_ documentos',
             'paginate': {
                'first': "Primero",
                'previous': "Anterior",
                'next': "Siguiente",
                'last': "Último"
            },
         }, 
         maxBytes=0,
         columnDefs=[
             {"width": "5px", "targets": [0]},
             {"width": "20px", "targets": [1]},
             {"width": "100px", "targets": [2]}
         ]
        )

draw_table(indice)
# Out:
# <table id="9c282901-4d48-415f-8b5d-9c07f8642e63" class="display"style="max-width:100%"><thead><th>Año</th><th>Grupo</th><th>Variable</th></thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [[2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-sistema-nervioso.csv\">enfermedades del sistema nervioso</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-ojo-y-anexos.csv\">enfermedades del ojo y anexos</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-oido-y-apofisis-mastoides.csv\">enfermedades del oido y apofisis mastoides</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-sistema-cardio-circulatorio.csv\">enfermedades del sistema cardio circulatorio</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-sistema-respiratorio.csv\">enfermedades del sistema respiratorio</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-sistema-digestivo.csv\">enfermedades del sistema digestivo</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-del-sistema-genitourinario.csv\">enfermedades del sistema genitourinario</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-de-piel-y-celular-subcutanea.csv\">enfermedades de piel y celular subcutanea</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-endocrinas-nutricionales-metabolicas.csv\">enfermedades endocrinas - nutricionales - metabolicas</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-sistema-osteomuscular-y-tejido-conjuntivo.csv\">enfermedades sistema osteomuscular y tejido conjuntivo</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-de-la-sangre-y-transtornos-inmunitarios.csv\">enfermedades de la sangre y transtornos inmunitarios</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_enfermedades-tumorales.csv\">enfermedades tumorales</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_complicaciones-embarazo-parto-y-puerperio.csv\">complicaciones embarazo, parto y puerperio</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_malformaciones-congenitas.csv\">malformaciones congenitas</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_traumatismos-y-envenenamiento.csv\">traumatismos y envenenamiento</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/datos/2001_clasificacion-general-sistemica_transtornos-mentales-y-del-comportamiento.csv\">transtornos mentales y del comportamiento</a>"], [2001, "clasificacion general sistemica", "<a href=\"https://mauforonda.github.io/vigilancia-epid ...

# %% [markdown]
# Y esta tabla muestra los datos para casos en una variable entre múltiples periodos, donde era posible agruparlos:

# %%
def draw_group_table(df):
    
    def link(dfi, name, link):
        return dfi[[link, name]].apply(lambda row: '<a href="{}">{}</a>'.format(row[0], row[1]), axis=1)
    
    dfi = df.copy()
    url_base = 'https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/'
    dfi['filename'] = dfi.filename.apply(lambda f: '<a href="{}{}">csv</a>'.format(url_base, f))
    dfi['Nombre'] = link(dfi, name='nombre_comun', link='filename')
    dfi = dfi[['nombre_comun', 'filename']]
    dfi.columns = ['Nombre', '']
    
    show(dfi, 
         order = [],
         hover = True,
         compact=True,
         scrollY="900px", 
         lengthMenu=[50,100],
         scrollCollapse=True,
         search={"caseInsensitive": True},
         paging=True,
         language={
             'lengthMenu': 'Mostrar _MENU_ filas',
             'search': '&#x1F50E;&#xFE0E;', 
             'processing': 'creando tabla ...', 
             'info': '', 
             'infoEmpty': '', 
             'infoFiltered':'_TOTAL_ documentos',
             'paginate': {
                'first': "Primero",
                'previous': "Anterior",
                'next': "Siguiente",
                'last': "Último"
            },
         }, 
         maxBytes=0,
         columnDefs=[
             {"width": "100px", "targets": [0]},
             {"width": "5px", "targets": [1]}
         ]
        )

draw_group_table(indice_agrupado)
# Out:
# <table id="b719c00b-646e-41ce-a70c-0e1bad1cbea3" class="display"style="max-width:100%"><thead><th>Nombre</th><th></th></thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [["Enfermedades del sistema nervioso entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_1_enfermedades-del-sistema-nervioso_2001_2003.csv\">csv</a>"], ["Enfermedades del ojo y anexos entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_2_enfermedades-del-ojo-y-anexos_2001_2003.csv\">csv</a>"], ["Enfermedades del oido y apofisis mastoides entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_3_enfermedades-del-oido-y-apofisis-mastoides_2001_2003.csv\">csv</a>"], ["Enfermedades del sistema cardio circulatorio entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_4_enfermedades-del-sistema-cardio-circulatorio_2001_2003.csv\">csv</a>"], ["Enfermedades del sistema respiratorio entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_5_enfermedades-del-sistema-respiratorio_2001_2003.csv\">csv</a>"], ["Enfermedades del sistema digestivo entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_6_enfermedades-del-sistema-digestivo_2001_2003.csv\">csv</a>"], ["Enfermedades del sistema genitourinario entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_7_enfermedades-del-sistema-genitourinario_2001_2003.csv\">csv</a>"], ["Enfermedades de piel y celular subcutanea entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_8_enfermedades-de-piel-y-celular-subcutanea_2001_2003.csv\">csv</a>"], ["Enfermedades endocrinas - nutricionales - metabolicas entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_9_enfermedades-endocrinas-nutricionales-metabolicas_2001_2003.csv\">csv</a>"], ["Enfermedades sistema osteomuscular y tejido conjuntivo entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_10_enfermedades-sistema-osteomuscular-y-tejido-conjuntivo_2001_2003.csv\">csv</a>"], ["Enfermedades de la sangre y transtornos inmunitarios entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_11_enfermedades-de-la-sangre-y-transtornos-inmunitarios_2001_2003.csv\">csv</a>"], ["Enfermedades tumorales entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_12_enfermedades-tumorales_2001_2003.csv\">csv</a>"], ["Complicaciones embarazo, parto y puerperio entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_13_complicaciones-embarazo-parto-y-puerperio_2001_2003.csv\">csv</a>"], ["Malformaciones congenitas entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_14_malformaciones-congenitas_2001_2003.csv\">csv</a>"], ["Traumatismos y envenenamiento entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_15_traumatismos-y-envenenamiento_2001_2003.csv\">csv</a>"], ["Transtornos mentales y del comportamiento entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_16_transtornos-mentales-y-del-comportamiento_2001_2003.csv\">csv</a>"], ["Otras causas entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/0_17_otras-causas_2001_2003.csv\">csv</a>"], ["Sarampion entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/1_1_sarampion_2001_2003.csv\">csv</a>"], ["Rubeola entre 2001 y 2004", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/1_2_rubeola_2001_2004.csv\">csv</a>"], ["Tosferina entre 2001 y 2003", "<a href=\"https://mauforonda.github.io/vigilancia-epidemiologica/agrupados/1_3_tosferina_2001_2003.csv\">csv</a>"], ["Difteria entre 2001 y 2007", "<a href=\"https://m ...

# %% [markdown]
# A continuación detallo el proceso de construcción de estos datos, que consiste en 3 pasos:
#
# 1. Construir un inventario de variables
# 2. Descargar cada datos disponible
# 3. Preparar los datos para que sean utilizados fácilmente

# %% [markdown]
# ## Un inventario de variables
#
# *Qué información está disponible?*
#
# El ministerio construye una página diferente para mostrar los datos de cada año. Es necesario consultar cada página y navegar los menús que ofrece para listar las variables y grupos de variables que exhibe. Algo interesante de estos tableros es que para entregar información, además de los parámetros que describen la consulta e identidad del usuario, requieren valores que describen el estado de navegación del usuario en el tablero durante la consulta anterior. Es decir que para mostrar una tabla en particular es necesario no sólo ejecutar la consulta correcta, sino la secuencia previa de consultas correctas que el servicio espera. Por suerte, estas limitaciones son fáciles de resolver.

# %%
# Información que el servidor espera de un usuario normal

cookies = {
    'ASP.NET_SessionId': 'es15y505g3h0e14ooob5ebns', # Place your own 🍪 🍪 🍪
}

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:98.0) Gecko/20100101 Firefox/98.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Origin': 'https://estadisticas.minsalud.gob.bo',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
}

# %%
# Some helper dicts

years = [
    {'year': 2001, 'pagina': 'Form_Vigi_2001.aspx'},
    {'year': 2002, 'pagina': 'Form_Vigi_2001.aspx'},
    {'year': 2003, 'pagina': 'Form_Vigi_2001.aspx'},
    {'year': 2004, 'pagina': 'Form_Vigi_2001.aspx'},
    {'year': 2005, 'pagina': 'Form_Vigi_2007.aspx'},
    {'year': 2006, 'pagina': 'Form_Vigi_2007.aspx'},
    {'year': 2007, 'pagina': 'Form_Vigi_2007.aspx'},
    {'year': 2008, 'pagina': 'Form_Vigi_2008.aspx'},
    {'year': 2009, 'pagina': 'Form_Vigi_2009.aspx'},
    {'year': 2010, 'pagina': 'Form_Vigi_2010.aspx'},
    {'year': 2011, 'pagina': 'Form_Vigi_2011.aspx'},
    {'year': 2012, 'pagina': 'Form_Vigi_2012.aspx'},
    {'year': 2013, 'pagina': 'Form_Vigi_2013.aspx'},
    {'year': 2014, 'pagina': 'Form_Vigi_2014_2.aspx'},
    {'year': 2015, 'pagina': 'Form_Vigi_2015_302a.aspx'},
    {'year': 2016, 'pagina': 'Form_Vigi_2016_302a.aspx'},
    {'year': 2017, 'pagina': 'Form_Vigi_2017_302a.aspx'},
    {'year': 2018, 'pagina': 'Form_Vigi_2018_302a.aspx'},
    {'year': 2019, 'pagina': 'Form_Vigi_2019_302a.aspx'},
    {'year': 2020, 'pagina': 'Form_Vigi_2020_302a.aspx'},
    {'year': 2021, 'pagina': 'Form_Vigi_2021_302a.aspx'}
]

state = {}

paginas = {y['year']:y['pagina'] for y in years}

# %%
# Functions to build a list of available datasets

def get_subvars(url, year, grvar):
    """
    Makes a list of every variable under a variable group and year.
    """
    
    data = {
        'ctl00$MainContent$WebPanel2_hidden': '',
        '__EVENTTARGET': 'ctl00$MainContent$WebPanel2$List_grvar',
        '__EVENTARGUMENT': '',
        '__LASTFOCUS': '',
        'ctl00$MainContent$WebPanel3_hidden': '%3CWebPanel%20Expanded%3D%22false%22%3E%3C/WebPanel%3E',
        'ctl00$MainContent$WebPanel2$List_gestion': str(year),
        'ctl00$MainContent$WebPanel2$List_fomulario': '302',
        'ctl00$MainContent$WebPanel2$Grupo': 'nomDepto',
        'ctl00$MainContent$WebPanel2$seleccion': '0',
        'ctl00$MainContent$WebPanel2$List_grvar': grvar
    }

    data = {**data, **state}
    
    response = requests.post(url, cookies=cookies, headers=headers, data=data)
    html = BeautifulSoup(response.text, 'html.parser')
    for node in ['__VIEWSTATE', '__VIEWSTATEGENERATOR', '__EVENTVALIDATION']:
        state[node] = html.select('#{}'.format(node))[0]['value']
    subvars = [{'subvar': option['value'], 'variable': option.get_text().strip()} for option in html.select('#MainContent_WebPanel2_Lista_subvar option')]
    return subvars

def get_variables(year, pagina):
    """
    Makes a list of all variables and variable groups for a year. 
    """
    
    data = {
        'ctl00$MainContent$WebPanel2_hidden': '',
        '__EVENTTARGET': 'ctl00$MainContent$WebPanel2$List_gestion',
        '__EVENTARGUMENT': '',
        '__LASTFOCUS': '',
        'ctl00$MainContent$WebPanel3_hidden': '%3CWebPanel%20Expanded%3D%22false%22%3E%3C/WebPanel%3E',
        'ctl00$MainContent$WebPanel2$List_gestion': str(year),
        'ctl00$MainContent$WebPanel2$List_fomulario': '302',
        'ctl00$MainContent$WebPanel2$List_grvar': '01',
        'ctl00$MainContent$WebPanel2$Grupo': 'nomDepto',
        'ctl00$MainContent$WebPanel2$seleccion': '0',
    }
    
    url = 'https://estadisticas.minsalud.gob.bo/Reportes_Vigilancia/{}'.format(pagina)
    variables[year] = []
    response = requests.get(url, cookies=cookies, headers=headers)
    html = BeautifulSoup(response.text, 'html.parser')
    for node in ['__VIEWSTATE', '__VIEWSTATEGENERATOR', '__EVENTVALIDATION']:
        state[node] = html.select('#{}'.format(node))[0]['value']
    response = requests.post(url, cookies=cookies, headers=headers, data={**data, **state})   
    html = BeautifulSoup(response.text, 'html.parser')
    for node in ['__VIEWSTATE', '__VIEWSTATEGENERATOR', '__EVENTVALIDATION']:
        state[node] = html.select('#{}'.format(node))[0]['value']
    for option in html.select('#MainContent_WebPanel2_List_grvar option'):
        grupo = option.get_text().strip()
        grvar = option['value']
        subvars = get_subvars(url, year, grvar)
        for v in subvars:
            variables[year].append({'grvar': grvar, 
                                    'grupo': grupo,
                                    'subvar': v['subvar'],
                                    'variable': v['variable']})

def format_variables(variables):
    """
    Format variables and variable groups so that they're meaningful and easier to harmonize in the future.
    """

    dfv = []
    for y in variables.keys():
        dfi = pd.DataFrame(variables[y])
        dfi.insert(0, 'year', y)
        dfv.append(dfi)
    dfv = pd.concat(dfv)

    dfv.variable = dfv.variable.str.replace('^[0-9\.\-]+ ', '', regex=True)
    dfv.variable = dfv.variable.str.lower()
    dfv.variable = dfv.variable.apply(lambda x: unicodedata.normalize('NFKD', x).encode('ascii', 'ignore').decode('ascii'))

    dfv.grupo = dfv.grupo.str.lower()
    dfv.grupo = dfv.grupo.apply(lambda x: unicodedata.normalize('NFKD', x).encode('ascii', 'ignore').decode('ascii'))
    
    return dfv.reset_index(drop=True)

# %%
# Make a list of all variables and variable groups for every year and format them right

variables = {}
for year in years:
    print(year['year'])
    get_variables(year['year'], year['pagina'])

dfv = format_variables(variables)

# %%
# save

dfv.to_csv('resources/variables.csv', index=False)

# %% [markdown]
# Encuentro más de 1500 variables que podría consultar entre 2001 y 2021. El inventario se ve así:

# %%
dfv
# Out:
#       year grvar                                         grupo subvar  \
# 0     2001    00               clasificacion general sistemica     01
# 1     2001    00               clasificacion general sistemica     02
# 2     2001    00               clasificacion general sistemica     03
# 3     2001    00               clasificacion general sistemica     04
# 4     2001    00               clasificacion general sistemica     05
# ...    ...   ...                                           ...    ...
# 1565  2021    16     eventos - notificacion inmediata parte ii     03
# 1566  2021    17  enfermedades transmitidas por vectores (etv)     01
# 1567  2021    17  enfermedades transmitidas por vectores (etv)     02
# 1568  2021    17  enfermedades transmitidas por vectores (etv)     04
# 1569  2021    18                            mortalidad materna     01
#
#                                           variable
# 0                enfermedades del sistema nervioso
# 1                    enfermedades del ojo y anexos
# 2       enfermedades del oido y apofisis mastoides
# 3     enfermedades del sistema cardio circulatorio
# 4            enfermedades del sistema respiratorio
# ...                                            ...
# 1565                            otros de excepcion
# 1566                                 leishmaniasis
# 1567                                  chagas agudo
# 1568                                       malaria
# 1569                    sospecha de muerte materna
#
# [1570 rows x 5 columns]

# %% [markdown]
# En esta tabla, los valores `grvar` y `subvar` son códigos que describen un grupo de variables y variables en el tablero de un año `year`. Estos códigos serán útiles para solicitar datos al servidor en la próxima sección. Las condiciones, códigos y forma de los datos varían demasiado entre distintos años. Por eso, para tener un proceso que funcione a través de todas estas condiciones y años es importante sostener la menor cantidad de supuestos sobre cómo realizar consultas correctas o cómo se ve una tabla específica.

# %% [markdown]
# ## Datos
#
# *Descargar todos los datos disponibles a nivel mensual y municipal.*
#
# Con el inventario en mano, el próximo paso es la descarga. Realizo consultas para cada variable, año y mes, que almaceno en documentos csv, uno para cada variable y año. Como no puedo predecir la forma que tendrá la tabla que produce el sistema, y éste tiende a nombrar columnas de maneras idiosincráticas, por ejemplo desagregando valores entre distintos rangos de edad, usando ocasionalmente sexo, etc., simplemente tomo todo lo que ofrece. Las únicas columnas sobre las que tengo control son las que creo, que describen las variables, años y municipios. Las variables y años están bien armonizadas gracias al índice. Y respecto al municipio, para tener datos que puedo cruzar fácilmente con otros sets de datos en la próxima sección construyo un diccionario que me permite armonizar códigos para municipios a través de todos los años.

# %%
def get_state(url, year):
    """
    Inicializa parámetros de estado para persuadir al sistema a que nos entregue datos
    """
    
    data = {
        'ctl00$MainContent$WebPanel2_hidden': '',
        '__EVENTTARGET': 'ctl00$MainContent$WebPanel2$List_gestion',
        '__EVENTARGUMENT': '',
        '__LASTFOCUS': '',
        'ctl00$MainContent$WebPanel3_hidden': '%3CWebPanel%20Expanded%3D%22false%22%3E%3C/WebPanel%3E',
        'ctl00$MainContent$WebPanel2$List_gestion': str(year),
        'ctl00$MainContent$WebPanel2$List_fomulario': '302',
        'ctl00$MainContent$WebPanel2$List_grvar': '01',
        'ctl00$MainContent$WebPanel2$Grupo': 'nomDepto',
        'ctl00$MainContent$WebPanel2$seleccion': '0',
    }
    
    response = requests.get(url, cookies=cookies, headers=headers)
    html = BeautifulSoup(response.text, 'html.parser')
    for node in ['__VIEWSTATE', '__VIEWSTATEGENERATOR', '__EVENTVALIDATION']:
        state[node] = html.select('#{}'.format(node))[0]['value']
        
    response = requests.post(url, cookies=cookies, headers=headers, data={**data, **state})   
    html = BeautifulSoup(response.text, 'html.parser')
    for node in ['__VIEWSTATE', '__VIEWSTATEGENERATOR', '__EVENTVALIDATION']:
        state[node] = html.select('#{}'.format(node))[0]['value']
        
def update_state(url, year, grvar):
    """
    Actualiza parámetros de estado para persuadir al sistema a que nos entregue datos
    """

    data = {
        'ctl00$MainContent$WebPanel2_hidden': '',
        '__EVENTTARGET': 'ctl00$MainContent$WebPanel2$List_grvar',
        '__EVENTARGUMENT': '',
        '__LASTFOCUS': '',
        'ctl00$MainContent$WebPanel3_hidden': '%3CWebPanel%20Expanded%3D%22false%22%3E%3C/WebPanel%3E',
        'ctl00$MainContent$WebPanel2$List_gestion': str(year),
        'ctl00$MainContent$WebPanel2$List_fomulario': '302',
        'ctl00$MainContent$WebPanel2$Grupo': 'nomMunicip',
        'ctl00$MainContent$WebPanel2$seleccion': '0',
        'ctl00$MainContent$WebPanel2$List_mes': '1',
        'ctl00$MainContent$WebPanel2$List_grvar': grvar
    }
    data = {**data, **state}
    
    response = requests.post(url, cookies=cookies, headers={**headers, **{'Referer': url}}, data=data)
    html = BeautifulSoup(response.text, 'html.parser')
    for node in ['__VIEWSTATE', '__VIEWSTATEGENERATOR', '__EVENTVALIDATION']:
        state[node] = html.select('#{}'.format(node))[0]['value']

def get_month(url, year, mes, grvar, subvar):
    """
    Descarga datos para un mes en una variable y año.
    """

    data = {
        'ctl00$MainContent$WebPanel2_hidden': '',
        '__EVENTTARGET': '',
        '__EVENTARGUMENT': '',
        '__LASTFOCUS': '',
        'ctl00$MainContent$WebPanel3_hidden': '%3CWebPanel%20Expanded%3D%22false%22%3E%3C/WebPanel%3E',
        'ctl00$MainContent$WebPanel2$List_gestion': str(year),
        'ctl00$MainContent$WebPanel2$List_fomulario': '302',
        'ctl00$MainContent$WebPanel2$Grupo': 'nomMunicip',
        'ctl00$MainContent$WebPanel2$seleccion': '0',
        'ctl00$MainContent$WebPanel2$Button1': ' Procesar',
        'ctl00$MainContent$WebPanel2$List_mes': str(mes),
        'MainContentxWebPanel3xmydatagrid': '',
        'MainContentxWebPanel3xmydatagrid2': '',
        'ctl00$MainContent$WebPanel2$List_grvar': grvar,
        'ctl00$MainContent$WebPanel2$Lista_subvar': subvar
    }
    data = {**data, **state}
    
    response = requests.post(url, cookies=cookies, headers={**headers, **{'Referer': url}}, data=data)
    html = BeautifulSoup(response.text, 'html.parser')
    table = html.select('#G_MainContentxWebPanel3xmydatagrid')[0]
    
    df = pd.read_html(str(table))[0]
    df = df.set_index(df.columns[0])
    df = df[~df.index.str.lower().str.contains('total')]
    
    return df
    
def get_dataset(year, grvar, subvar, grupo, variable):
    """
    Descarga datos para cada mes en una variable y año.
    """
    
    year_data = []
    url = 'https://estadisticas.minsalud.gob.bo/Reportes_Vigilancia/{}'.format(paginas[year])
    get_state(url, year)
    update_state(url, year, grvar)
    for mes in range(1,13):
        mes_data = get_month(url, year, mes, grvar, subvar)
        mes_data.insert(0, 'mes', dt.date(year, mes, 1))
        year_data.append(mes_data)
    year_data = pd.concat(year_data)
    year_data.insert(0, 'variable', variable)
    year_data.insert(0, 'grupo', grupo)
    filename = 'dirty/{}_{}_{}.csv'.format(year, slugify(grupo), slugify(variable))
    indice.append(dict(year=year, filename=filename, grvar=grvar, grupo=grupo, subvar=subvar, variable=variable))
    year_data.to_csv(filename)

# %%
indice = []

# Descargar datos para cada fila en el inventario y simultáneamente construir un índice

for i, row in dfv.iterrows():
    clear_output(wait=True)
    print('{}/{} : {} en {}'.format(i+1, len(dfv), row['variable'], row['year']))
    get_dataset(row['year'], row['grvar'], row['subvar'], row['grupo'], row['variable'])

indice = pd.DataFrame(indice)
indice.to_csv('snis/resources/indice.csv', index=False)

# %% [markdown]
# Además de seguir las reglas mínimas que el servicio demanda para acceder a datos, no hago nada fancy en estas consultas. Son consultas secuenciales, en parte porque no quiero arriesgar degradar la disponibilidad del sitio y también porque es el proceso más sencillo de programar y evaluar. En total debe haber tomado alrededor de 9 horas de consultas y, si bien el proceso es reproducible, espero que no sea algo que deba hacerse de manera rutinaria.

# %% [markdown]
# ## Limpieza
#
# *Que cada tabla tenga una forma predecible y municipios armonizados.*
#
# Finalmente, pongo los datos en una estructura simple y extensible. Las primeras columnas de todos los sets de datos describen el código INE del municipio, el nombre del municipio que ofrece el tablero, el grupo de variable, el nombre de la variable y el mes de los valores. Para tener los códigos INE, construyo un diccionario que mapea cada nombre de municipio con su código, utilizando las tablas que publica el ministerio de salud sobre la estructura de establecimientos entre 2005 y 2021. Por suerte, los nombres en estas tablas y la base de datos de vigilancia epidemiológica son las mismas, debido a que el reporte se suele realizar mediante un sistema que consume listas similares publicadas periódicamente. El resto de las columnas consisten en todos los datos que ofrece el sistema, a veces desagregados por rangos de edad, sexo, si la atención fue prestada en el establecimiento o fuera, etc. No hago más que la limpieza más simple sobre estas columnas, suficiente como para que sean utilizadas rápidamente en el futuro y sin muchos juicios sobre cómo deberían verse. Con esta información es fácil agregar valores de condiciones a través de varios años y cruzarlos con información a nivel municipal, como por ejemplo indicadores de los Objetivos de Desarrollo Sostenible.

# %%
def format_vigilancia(indice_seleccion, municipio_dict):
    
    errores = []
    len_seleccion = len(indice_seleccion)

    for i, f in enumerate(indice_seleccion.filename):
        clear_output(wait=True)
        print('{} / {}'.format(i+1, len_seleccion))
        try:

            dfi = pd.read_csv('dirty/{}'f)

            if dfi.mes.isna().sum() > 0:
                header = dfi[dfi.mes.isna()][dfi.columns[4:]].to_dict()
                header = ['_'.join([slugify(k)] + [slugify(header[k][kk]) for kk in header[k].keys() if type(header[k][kk]) == str ]) for k in header.keys()]
                dfi = dfi[dfi.mes.notna()]
                dfi.columns = ['municipio', 'grupo', 'variable', 'mes'] + header

            else:
                dfi = dfi.rename(columns={'Municipio':'municipio'})

            dfi.insert(0, 'codigo_municipio', dfi.municipio.map(municipio_dict))
            dfi.to_csv('datos/{}'.format(f.split('/')[1]), index=False)

        except Exception as e:
            errores.append({'filename': f, 'error': e})

    return errores

def listar_municipios1(f):
    
    municipios_snis = []

    establecimientos = pd.ExcelFile(f)

    for s in establecimientos.sheet_names:
        e = pd.read_excel(establecimientos, sheet_name=s, header=2)
        e = e[['COD_MUNICIPIO', 'MUNICIPIO']]
        e = e.drop_duplicates()
        municipios_snis.append(e)

    municipios_snis = pd.concat(municipios_snis)
    municipios_snis = municipios_snis[municipios_snis.COD_MUNICIPIO.notna()]
    municipios_snis['COD_MUNICIPIO'] = municipios_snis.COD_MUNICIPIO.astype(int)
    municipios_snis['MUNICIPIO'] = municipios_snis.MUNICIPIO.str.strip()
    municipios_snis = municipios_snis.drop_duplicates()
    
    return municipios_snis

def listar_municipios2(f):
    e = pd.read_excel(f, sheet_name='BASE DE DATOS', header=3)
    e = e[['COD_MUN', 'MUN']]
    e.columns = ['COD_MUNICIPIO', 'MUNICIPIO']
    e = e[e.MUNICIPIO.notna()]
    e['COD_MUNICIPIO'] = e.COD_MUNICIPIO.astype(int)
    e['MUNICIPIO'] = e.MUNICIPIO.str.strip()
    e = e.drop_duplicates()
    return e

# %%
# Construir un diccionario para armonizar municipios

municipios_snis = pd.concat([
    listar_municipios1('snis/resources/Establecimientos 2005_2017.xlsx'), 
    listar_municipios2('snis/resources/ESTRUCTURA DE EE.SS. GESTION 2021_DASHBOARDcerrado oficial.xlsx')
]).drop_duplicates()

municipios_snis['MUNICIPIO'] = municipios_snis.MUNICIPIO.apply(lambda x: ' '.join(x.split()))
municipios_dict = municipios_snis.set_index('MUNICIPIO').COD_MUNICIPIO.to_dict()

# %%
errores = format_vigilancia(indice, municipios_dict)
# Out:
# 1570 / 1570

# %% [markdown]
# Para terminar, así es como se ve uno de los más 1500 sets de datos escogido aleatoriamente:

# %%
pd.read_csv('datos/{}'.format(indice.sample()['filename'].iloc[0]))
# Out:
#       codigo_municipio                      municipio  \
# 0                51302                         ACACIO
# 1                20201                      ACHACACHI
# 2                20104                      ACHOCALLA
# 3                30201                        AIQUILE
# 4                31303                         ALALAY
# ...                ...                            ...
# 1935             31201                   TOTORA(CBBA)
# 1936             41301                    TOTORA(ORR)
# 1937             31302                      VILA VILA
# 1938             10801                  VILLA SERRANO
# 1939             11001  VILLA VACA GUZMAN (MUYUPAMPA)
#
#                                 grupo      variable         mes  < de 1 año-H  \
# 0     clasificacion general sistemica  otras causas  2002-01-01             1
# 1     clasificacion general sistemica  otras causas  2002-01-01             1
# 2     clasificacion general sistemica  otras causas  2002-01-01             1
# 3     clasificacion general sistemica  otras causas  2002-01-01            18
# 4     clasificacion general sistemica  otras causas  2002-01-01             0
# ...                               ...           ...         ...           ...
# 1935  clasificacion general sistemica  otras causas  2002-12-01             0
# 1936  clasificacion general sistemica  otras causas  2002-12-01             0
# 1937  clasificacion general sistemica  otras causas  2002-12-01             1
# 1938  clasificacion general sistemica  otras causas  2002-12-01             4
# 1939  clasificacion general sistemica  otras causas  2002-12-01             5
#
#       < de 1 año-M  1 a 4 años-H  1 a 4 años-M  5 a 14 años-H  5 a 14 años-M  \
# 0                0             0             0              0              0
# 1                0             3             0              5              0
# 2                0             3             0              6              0
# 3                0            13             0             10              0
# 4                0             1             0              0              0
# ...            ...           ...           ...            ...            ...
# 1935             0             0             0              1              0
# 1936             0             1             0              5              0
# 1937             0             1             0              0              0
# 1938             0            23             0             11              0
# 1939             0            36             0             19              0
#
#       15 a 59 años-H  15 a 59 años-M  60 y más-H  60 y más-M  TOTAL-H  \
# 0                  5               0           2           0        8
# 1                 27               0           8           0       44
# 2                 10               0           6           0       26
# 3                 66               0           8           0      115
# 4                  5               0           1           0        7
# ...              ...             ...         ...         ...      ...
# 1935              18               0           1           0       20
# 1936               1               0           0           0        7
# 1937               2               0           1           0        5
# 1938              41               0           4           0       83
# 1939             115               0          12           0      187
#
#       TOTAL-M  TOTAL
# 0           0      8
# 1           0     44
# 2           0     26
# 3           0    115
# 4           0      7
# ...       ...    ...
# 1935        0     20
# 1936        0      7
# 1937        0      5
# 1938        0     83
# 1939        0    187
#
# [1940 rows x 18 columns]

# %% [markdown]
# ## Agrupamiento
#
# Cada set de datos representa el número de casos clasificados en una variable para un año, desagregado por meses y municipios. Si bien una misma variable es monitoreada en múltiples periodos, sus nombres y las formas de la tabla que produce el sistema suelen cambiar. No quiero hacer juicios de valor sobre qué nombres representan la misma variable o cómo debería armonizar tablas muy diferentes. Sin embargo, sería muy útil tener información que represente periodos más largos que 1 sólo año. Para ésto, agrupo datos para una misma variable cuya tabla tenga la misma forma a través de múltiples años. Este agrupamiento reduce el número de sets de datos de 1570 series anuales a 469 documentos.

# %%
indice = pd.read_csv('resources/indice.csv')
unicos = indice[['grvar', 'subvar', 'grupo', 'variable']].drop_duplicates(subset=['grvar', 'subvar', 'variable']).reset_index(drop=True)
unicos = unicos[unicos.variable.notna()]

# %%
indice_agrupado = []

for i, condicion in unicos.iterrows():
    
    schemas = []
    for e, row in indice[(indice.grvar == condicion.grvar) & (indice.subvar == condicion.subvar) & (indice.variable == condicion.variable)].iterrows():
        schemas.append({**row, **{'columns': ', '.join(pd.read_csv('datos/' + row.filename).columns.tolist())}})
    schemas = pd.DataFrame(schemas)
    print('{}. {} {} {} : {} schemas'.format(i, condicion.grvar, condicion.subvar, condicion.variable, len(schemas['columns'].drop_duplicates())))
    
    for group in [g for c, g in schemas.groupby('columns')]:
        group_df = pd.concat([pd.read_csv('datos/' + fn) for fn in group.filename])
        group_dict = {**group[['grvar', 'subvar', 'variable']].iloc[0].to_dict(), **{'desde': group.iloc[0].year, 'hasta': group.iloc[-1].year}}
        group_fn = '{}_{}_{}_{}_{}.csv'.format(*[slugify(str(group_dict[k])) for k in group_dict.keys()])
        group_dict['filename'] = group_fn
        
        group_df.to_csv('agrupados/' + group_fn, index=False)
        indice_agrupado.append(group_dict)
        
indice_agrupado = pd.DataFrame(indice_agrupado)
indice_agrupado['nombre_comun'] = indice_agrupado.apply(lambda r: '{} entre {} y {}'.format(r['variable'][0].upper() + r['variable'][1:], r['desde'], r['hasta']) if r['desde'] != r['hasta'] else '{} en {}'.format(r['variable'][0].upper() + r['variable'][1:], r['hasta']), axis=1)
indice_agrupado.to_csv('resources/indice_agrupado.csv', index=False)
# Out:
# 0. 0 1 enfermedades del sistema nervioso : 1 schemas
# 1. 0 2 enfermedades del ojo y anexos : 1 schemas
# 2. 0 3 enfermedades del oido y apofisis mastoides : 1 schemas
# 3. 0 4 enfermedades del sistema cardio circulatorio : 1 schemas
# 4. 0 5 enfermedades del sistema respiratorio : 1 schemas
# 5. 0 6 enfermedades del sistema digestivo : 1 schemas
# 6. 0 7 enfermedades del sistema genitourinario : 1 schemas
# 7. 0 8 enfermedades de piel y celular subcutanea : 1 schemas
# 8. 0 9 enfermedades endocrinas - nutricionales - metabolicas : 1 schemas
# 9. 0 10 enfermedades sistema osteomuscular y tejido conjuntivo : 1 schemas
# 10. 0 11 enfermedades de la sangre y transtornos inmunitarios : 1 schemas
# 11. 0 12 enfermedades tumorales : 1 schemas
# 12. 0 13 complicaciones embarazo, parto y puerperio : 1 schemas
# 13. 0 14 malformaciones congenitas : 1 schemas
# 14. 0 15 traumatismos y envenenamiento : 1 schemas
# 15. 0 16 transtornos mentales y del comportamiento : 1 schemas
# 16. 0 17 otras causas : 1 schemas
# 17. 1 1 sarampion : 1 schemas
# 18. 1 2 rubeola : 1 schemas
# 19. 1 3 tosferina : 1 schemas
# 20. 1 4 difteria : 2 schemas
# 21. 1 6 fiebre amarilla : 2 schemas
# 22. 1 7 dengue hemorragico : 2 schemas
# 23. 1 9 poliomielitis : 1 schemas
# 24. 2 9 fiebre hemorragica : 1 schemas
# 25. 2 10 tifus exantematico : 1 schemas
# 26. 2 11 peste : 2 schemas
# 27. 2 12 meningitis meningococcica : 1 schemas
# 28. 2 13 colera : 2 schemas
# 29. 2 14 hantavirus : 1 schemas
# 30. 2 15 rabia (humana/canina) : 1 schemas
# 31. 2 16 sida mujeres : 1 schemas
# 32. 2 17 sida hombres : 1 schemas
# 33. 2 18 sifilis : 1 schemas
# 34. 2 19 meningitis por hemophilus influenzae : 1 schemas
# 35. 2 20 meningitis tuberculosa : 1 schemas
# 36. 4 1 tetanos neonatal : 2 schemas
# 37. 4 2 tetanos de adulto : 1 schemas
# 38. 4 3 hepatitis viral : 2 schemas
# 39. 4 5 eruptivas : 1 schemas
# 40. 4 6 paralisis flacida : 1 schemas
# 41. 4 7 rabia canina : 1 schemas
# 42. 4 8 tosferina (3*) : 1 schemas
# 43. 4 9 difteria (4*) : 1 schemas
# 44. 4 10 fiebre amarilla (6*) : 1 schemas
# 45. 4 11 rabia humana (7*) : 1 schemas
# 46. 5 1 its mujer con ulcera genital : 1 schemas
# 47. 5 2 its hombre con ulcera genital : 1 schemas
# 48. 5 3 its home con flujo uretral : 1 schemas
# 49. 5 4 sida o vih + : 1 schemas
# 50. 5 5 sifilis congenita - nacido vivo : 1 schemas
# 51. 5 6 sifilis congenita - mortinato : 1 schemas
# 52. 6 1 diarrea : 1 schemas
# 53. 6 3 neumonia : 2 schemas
# 54. 6 5 enfermedad de hansen : 1 schemas
# 55. 6 6 sintomatico respiratorio : 1 schemas
# 56. 6 7 fiebre hemorragica (13*) : 1 schemas
# 57. 6 8 enfermedad respiratoria hanta (14*) : 1 schemas
# 58. 6 9 tifus exantematico (15*) : 1 schemas
# 59. 6 10 meningitis (17, 18*, 19*) : 1 schemas
# 60. 7 2 meningitis tuberculosa en menores de 5 anos : 1 schemas
# 61. 7 3 tuberculosis pulmonar baar (+) nuevos : 1 schemas
# 62. 7 4 tuberculosis pulmonar baar (-) : 1 schemas
# 63. 7 5 tuberculosis extrapulmonar : 2 schemas
# 64. 7 6 tuberculosis pulmonar baar (+) prevamente tratados : 1 schemas
# 65. 8 1 violencia contra el hombre : 1 schemas
# 66. 8 2 violencia contra la mujer : 1 schemas
# 67. 8 3 violencia contra el nino : 1 schemas
# 68. 8 4 violencia contra la nina : 1 schemas
# 69. 9 1 muerte materna : 4 schemas
# 70. 9 2 muerte rn menor de 7 dias : 4 schemas
# 71. 9 4 muerte menor de 5 anos por diarrea : 2 schemas
# 72. 9 5 muerte menor de 5 anos por neumonia : 4 schemas
# 73. 9 6 muerte menor de 5 anos por otras causas : 4 schemas
# 74. 9 7 otras muertes en personas mayores de 5 anos : 3 schemas
# 75. 9 8 muerte por malaria (p. falciparum) : 2 schemas
# 76. 10 5 hemorragia de la primera mitad del embarazo : 1 schemas
# 77. 10 6 parto de adolecente (menor de 20 anos) : 1 schemas
# 78. 10 7 parto de mujer anosa (mayor de 35 anos) : 1 schemas
# 79. 10 8 parturienta con hijo anterior vivo : 1 schemas
# 80. 10 9 parturienta con hijo anterior muerto : 1 schemas
# 81. 11 1 clasificacion a y b : 2 schemas
# 82. 11 2 clasificacion c : 2 schemas
# 83. 11 3 clasificacion d : 2 schemas
# 84. 11 4 clasificacion e : 2 schemas
# 85. 11 5 clasificacion f : 2 schemas
# 86. 13 2 alimentos (brotes) : 1 schemas
# 87. 13 3 alcohol : 1 schemas
# 88. 13 4 drogas : 1 schemas
# 89. 13 5 organosfosforados : 1 schemas
# 90. 14 1 malaria : 1 schemas
# 91. 14 2 leishmaniasis : 1 schemas
# 92. 14 3 dengue : 1 schemas
# 93. 14 4 enfermedades de chagas aguda : 1 schemas
# 94. 15 1 muerte materna : 1 schemas
# 95. 15 2 muerte por otras causas : 1 schemas
# 96. 1 1 sarampion / rubeola : 2 schemas
# 97. 1 3 tos ferina : 2 schemas
# 98. 1 5 paralisis flacida aguda : 2 schemas
# 99. 2 9 fiebre hemorrag. bol : 2 schemas
# 100. 2 12 menin. meningococica : 2 schemas
# 101. 2 14 enfer. por hanta virus : 2 schemas
# 102. 3 14 numero de personas mordidas por can sospechoso de rabia : 1 schemas
# 103. 3 15 rabia en canes : 1 schemas
# 104. 3 16 desastres y emergencias : 1 schemas
# 105. 4 2 tetanos del adulto : 1 schemas
# 106. 4 3 hepatitis : 1 schemas
# 107. 4 4 parotiditis : 2 schemas
# 108. 5 1 mujer con ulcera genital : 1 schemas
# 109. 5 2 hombre con ulcera genital : 1 schemas
# 110. 5 3 hombre con flujo uretral (uretritis) : 1 schemas
# 111. 5 4 sida : 1 schemas
# 112. 6 1 enfermedad diarreica aguda : 2 schemas
# 113. 6 2 ira sin neumonia : 2 schemas
# 114. 6 4 lepra : 1 schemas
# 115. 7 1 sintomatico respiratorio : 1 schemas
# 116. 7 2 meningitis tb en menores de 5 anos : 2 schemas
# 117. 7 3 tuberculosis pulmonar baar + nuevos : 1 schemas
# 118. 7 4 tuberculosis pulmonar baar - nuevos : 1 schemas
# 119. 8 1 hombres : 1 schemas
# 120. 8 2 mujeres : 1 schemas
# 121. 9 3 muerte menor de 1 ano : 3 schemas
# 122. 10 1 aborto : 1 schemas
# 123. 10 2 hemorragia del parto o puerperio : 1 schemas
# 124. 10 3 51embarazo en adolecente (menor de 20 anos) : 1 schemas
# 125. 10 4 preeclampsia severa/eclampsia : 2 schemas
# 126. 13 1 plaguicidas : 2 schemas
# 127. 1 8 dengue clasico : 2 schemas
# 128. 2 15 rabia humana : 2 schemas
# 129. 3 14 numero de personas mordidas por animal sospechoso de rabia : 1 schemas
# 130. 6 1 enfermedad  diarreica aguda : 1 schemas
# 131. 6 4 malaria : 2 schemas
# 132. 6 5 leishmaniasis : 2 schemas
# 133. 7 2  meningitis tb en menores de 5 anos : 1 schemas
# 134. 7 6 enfermos curados : 1 schemas
# 135. 7 7 fracaso terapeutico : 1 schemas
# 136. 7 8 lepra * : 1 schemas
# 137. 9 4 muerte  menor de 5 anos por diarrea : 2 schemas
# 138. 10 1 hemorragia de la primera mitad del embarazo (<22 sem) : 2 schemas
# 139. 10 3 embarazo en adolecente (menor de 20 anos) : 2 schemas
# 140. 11 1 sobrepeso (s) : 2 schemas
# 141. 11 2 nutricion normal (n) : 2 schemas
# 142. 11 3 desnutricion leve (l) : 2 schemas
# 143. 11 4 desnutricion moderada (m) : 2 schemas
# 144. 11 5 desnutricion grave (g) : 2 schemas
# 145. 12 1 talla normal (n) : 1 schemas
# 146. 12 2 talla baja leve (l) : 1 schemas
# 147. 12 3 talla baja moderada (m) : 1 schemas
# 148. 12 4 talla baja grave (g) : 1 schemas
# 149. 4 2 tetanos : 2 schemas
# 150. 5 1 ulcera genital : 2 schemas
# 151. 5 3 flujo uretral (uretritis) : 2 schemas
# 152. 5 4 sida * : 2 schemas
# 153. 7 8 lepra paucibacilar* : 2 schemas
# 154. 7 9 lepra multibacilar * : 2 schemas
# 155. 8 1 intrafamiliar : 1 schemas
# 156. 8 2 otras violencias (causas externas) : 1 schemas
# 157. 10 2 nro. de embarazadas enflaquecidas (desnutridas) : 1 schemas
# 158. 11 1 nutricion superior (ns) : 1 schemas
# 159. 12 1 global peso bajo (m + g)) : 1 schemas
# 160. 12 2 cronica talla baja (m + g) : 1 schemas
# 161. 13 2 otras intoxicaciones : 1 schemas
# 162. 2 16 no de personas mordidas por animal : 1 schemas
# 163. 2 17 influenza aviar - pandemica : 1 schemas
# 164. 7 10 rafa reacciones adversas (leves y moderadas) : 1 schemas
# 165. 7 11 rafa reacciones adversas (graves) : 1 schemas
# 166. 8 1 intrafamiliar/domestica : 1 schemas
# 167. 8 2 otras violencias (accidentes, agresiones, leer instructivo) : 1 schemas
# 168. 9 7 otras muertes en mayores de 5 anos : 1 schemas
# 169. 11 6 desnutrida : 1 schemas
# 170. 11 7 obesidad (o) : 1 schemas
# 171. 13 2 otras intoxicaciones (drogas, farmacos, alcohol, leer instructivo) : 1 schemas
# 172. 14 1 talla normal (t n) : 1 schemas
# 173. 14 2 talla baja (tb) : 1 schemas
# 174. 1 5 paralisis flacida aguda (polio) : 1 schemas
# 175. 1 9 fiebre hemorragica boliviana : 1 schemas
# 176. 1 10 peste : 1 schemas
# 177. 2 10 meningitis meningococica : 1 schemas
# 178. 2 14 enfermedad por hanta virus : 1 schemas
# 179. 2 17 influenza / pandemica : 1 schemas
# 180. 2 18 rabia canina : 1 schemas
# 181. 2 19 leptospirosis : 1 schemas
# 182. 2 22 mordedura de serpiente : 1 schemas
# 183. 4 1 tetanos neonatal / adulto : 1 schemas
# 184. 5 5 dolor abdominal/ edema de escroto : 1 schemas
# 185. 5 6 vih mujer embarazada : 1 schemas
# 186. 5 7 vih poblacion en general : 1 schemas
# 187. 6 4 malaria sospechosos : 1 schemas
# 188. 6 5 leishmaniasis sospechosos : 1 schemas
# 189. 6 6 no de personas expuestas al virus rabico(mordida, : 1 schemas
# 190. 6 7 chagas agudo : 1 schemas
# 191. 6 8 malaria confirmados : 1 schemas
# 192. 6 9 leishmaniasis confirmados : 1 schemas
# 193. 7 2 tuberculosis meningea : 1 schemas
# 194. 7 10 rafa (leves y moderadas) : 1 schemas
# 195. 7 11 rafa (graves) : 1 schemas
# 196. 8 2 otras violencias (accidentes, agresiones, leer in : 1 schemas
# 197. 8 3 hechos de transito : 1 schemas
# 198. 8 4 accidentes : 1 schemas
# 199. 9 8 muerte menor de 5 anos por neumonia : 1 schemas
# 200. 10 1 hemorragia de la primera mitad del embarazo (<22 : 1 schemas
# 201. 10 2 embarazo en adolescente (< de 20 anos) : 1 schemas
# 202. 10 3 hemorragia de la primera mitad del embarazo (<22 : 1 schemas
# 203. 11 6 embarazada desnutrida : 1 schemas
# 204. 13 2 otras intoxicaciones (drogas, farmacos, etc.) : 1 schemas
# 205. 13 3 enf. transmitidas por alimentos (e.t.a.) : 1 schemas
# 206. 15 1 riada : 3 schemas
# 207. 15 2 helada/granizo/nevada : 3 schemas
# 208. 15 3 incendio : 3 schemas
# 209. 16 1 deslizamiento : 1 schemas
# 210. 16 2 inundacion : 3 schemas
# 211. 16 3 otros de excepcion : 3 schemas
# 212. 5 3 flujo uretral (vaginal) : 1 schemas
# 213. 5 5 sifilis en la mujer embarazada : 1 schemas
# 214. 9 8 muerte menor de 5 anos por desnutricion aguda gra : 1 schemas
# 215. 1 11 sarampion / rubeola : 2 schemas
# 216. 1 12 sindrome de rubeola congenita : 2 schemas
# 217. 1 13 tos ferina/coqueluche : 2 schemas
# 218. 1 14 difteria : 2 schemas
# 219. 1 15 paralisis flacida aguda (polio) : 2 schemas
# 220. 1 16 fiebre amarilla : 2 schemas
# 221. 1 17 dengue grave : 2 schemas
# 222. 1 18 fiebre hemorragica boliviana : 2 schemas
# 223. 1 19 peste : 2 schemas
# 224. 1 20 enfermedad meningococica : 2 schemas
# 225. 1 21 colera : 2 schemas
# 226. 1 22 enfermedad por hanta virus : 2 schemas
# 227. 1 23 rabia en perros : 2 schemas
# 228. 1 24 rabia humana : 2 schemas
# 229. 1 25 influenza  (irag ,iragi y eti) : 2 schemas
# 230. 1 26 leptospirosis : 2 schemas
# 231. 4 5 tetanos neonatal / adulto : 2 schemas
# 232. 4 6 hepatitis viral a* : 2 schemas
# 233. 4 7 hepatitis viral b o c* : 2 schemas
# 234. 4 8 parotiditis : 2 schemas
# 235. 4 9 varicela : 2 schemas
# 236. 5 8 ulcera genital : 2 schemas
# 237. 5 9 sifilis congenita : 2 schemas
# 238. 5 10 sifilis en la mujer embarazada* : 2 schemas
# 239. 5 11 flujo uretral/vaginal : 2 schemas
# 240. 5 12 gonorrea : 2 schemas
# 241. 5 13 verruga genital : 2 schemas
# 242. 5 14 prueba rapida reactiva de vih en  mujer embarazada : 2 schemas
# 243. 5 15 prueba rapida reactiva de vih en poblacion en general : 2 schemas
# 244. 6 10 enfermedad diarreica aguda : 2 schemas
# 245. 6 11 ira sin neumonia : 2 schemas
# 246. 6 12 neumonia : 2 schemas
# 247. 6 13 no de personas expuestas al virus rabico : 2 schemas
# 248. 6 14 n de personas con mordedura de serpientes : 2 schemas
# 249. 6 15 n de personas con picadura de animales ponzonosos : 2 schemas
# 250. 7 12 tuberculosis meningea : 2 schemas
# 251. 7 13 reaccion adversa  a farmacos antituberculosos (rafa) : 2 schemas
# 252. 7 14 reaccion  adversa a farmacos antituberculosos rafa (graves) : 2 schemas
# 253. 7 15 lepra paucibacilar : 2 schemas
# 254. 7 16 lepra multibacilar : 2 schemas
# 255. 8 5 violencia en la familia : 2 schemas
# 256. 8 6 violencia sexual (familiar, domestica y/o en otros ambitos) : 2 schemas
# 257. 8 7 otras violencias por lesiones autoinflingidas y colectivas : 2 schemas
# 258. 8 8 no de casos presentados por hechos de transito : 2 schemas
# 259. 8 9 no de casos presentados por otros accidentes : 2 schemas
# 260. 9 9 muerte menor de 5 anos por diarrea : 3 schemas
# 261. 9 10 muerte menor de 5 anos por neumonia : 3 schemas
# 262. 9 11 muerte menor de 5 anos por desnutricion aguda grave : 3 schemas
# 263. 9 12 muerte menor de 5 anos por otras causas : 3 schemas
# 264. 9 13 otras muertes en mayores de 5 anos : 3 schemas
# 265. 10 5 hemorragia de la primera mitad del embarazo (< 22 sem) aborto : 2 schemas
# 266. 10 6 gestantes y puerperas con sepsis : 2 schemas
# 267. 10 7 preeclampsia severa : 2 schemas
# 268. 10 8 eclampsia : 2 schemas
# 269. 13 4 plaguicidas : 3 schemas
# 270. 13 5 enf. transmitidas por alimentos (e.t.a.) : 3 schemas
# 271. 13 6 otras intoxicaciones (drogas, farmacos, alcohol etc.) : 3 schemas
# 272. 16 1 deslizamiento/sismo/terremoto : 2 schemas
# 273. 17 1 leishmaniasis : 2 schemas
# 274. 17 2 chagas agudo : 2 schemas
# 275. 17 3 dengue : 2 schemas
# 276. 17 4 malaria : 2 schemas
# 277. 18 1 muerte materna notificada : 3 schemas
# 278. 18 2 muerte materna confirmada : 3 schemas
# 279. 19 1 muerte fetal (obito) confirmada : 2 schemas
# 280. 19 2 muerte neonatal  temprana (0-6 dias) confirmada : 2 schemas
# 281. 19 3 muerte neonatal  tardia (7-27 dias) confirmada : 2 schemas
# 282. 19 4 muerte menor de 28 dias por sepsis : 2 schemas
# 283. 19 5 muerte menor de 28 dias por asfixia perinatal : 2 schemas
# 284. 19 6 muerte de 28 dias a menor de 1 ano : 2 schemas
# 285. 1 27 chikungunya : 2 schemas
# 286. 1 28 zika : 2 schemas
# 287. 1 29 anomalia congenita : 1 schemas
# 288. 1 30 microcefalia : 1 schemas
# 289. 1 31 trastorno neurologico : 1 schemas
# 290. 1 32 sind. guillain barre : 1 schemas
# 292. 1 29 anomalia congenita asociado al zika : 1 schemas
# 293. 1 30 microcefalia asociado al zika : 1 schemas
# 294. 1 31 trastorno nuerologico asociado al zika : 1 schemas
# 295. 1 32 sind. guillain barre asociado al zika : 1 schemas
# 296. 1 29 dengue con signos de alarma : 1 schemas
# 297. 1 30 dengue sin signos de alarma : 1 schemas
# 298. 1 31 muerte de mujer 10-59 anos : 1 schemas
# 299. 1 18 fiebre hemorragica : 1 schemas
# 300. 1 23 rabia canina : 1 schemas
# 301. 1 31 otras meningitis : 1 schemas
# 302. 1 32 sindrome hemolitico uremico : 1 schemas
# 303. 1 33 covid-19 : 1 schemas
# 304. 6 14 n de personas con evenenamiento por mordedura de serpientes venenosas : 1 schemas
# 305. 6 15 n de personas con envenenamiento por aracnidos : 1 schemas
# 306. 1 34 sindrome inflamatorio multisistemico asociado con covid-19 : 1 schemas
# 307. 1 35 esavi (eventos supuestamente atribuidos a la vacunacion y/o inmunizacion) : 1 schemas
# 308. 4 10 otras hepatitis virales : 1 schemas
# 309. 9 14 sospecha de muerte por dengue : 1 schemas
# 310. 9 15 sospecha de muerte por covid-19 : 1 schemas
# 311. 13 7 organofosforados , carbamatos : 1 schemas
# 312. 13 8 halogenados : 1 schemas
# 313. 13 9 herbicida y fungicida : 1 schemas
# 314. 13 10 otros plaguicidas/insecticidas : 1 schemas
# 315. 18 1 sospecha de muerte materna : 1 schemas

# %% [markdown]
# ## Columnas con descripciones más significativas
#
# Un problema con el proceso hasta este momento es cómo las columnas en cada set de datos tienen nombres difíciles de interpretar, resultado de aplanar las tablas que produce el sistema del snis en una forma uniforme. Para tener columnas más fáciles de interpretar infiero los atributos que representan y construyo un mejor nombre. Cada columna puede describir casos que ocurren dentro o fuera de establecimientos de salud, hacer referencia a hombres o mujeres, representar distintos rangos de edad y referirse a poblaciones o eventos particulares. Identifico estos atributos y construyo mejores nombres de columna que aplico a todos los documentos producidos.

# %%
patterns = { 
    
    'dentro':{
        'dentro de establecimientos': '(dentro)|(\-d[\-\_])|(Dentro)|(DENTRO)',
        'fuera de establecimientos': '(fuera)|(\-f[\-\_])|(Fuera)|(FUERA)'
    },
    
    'sexo': {
        'hombres': '(-H$)|(_masculino$)|(-m$)|(_masculino-1$)|(H1$)',
        'mujeres': '(-M$)|(_femenino$)|(-f$)|(_femenino-1$)|(M1$)|(mujer)'
    },
    
    'edad': {
        'menores a 1 año': '(< de 1)',
        'de 1 a 4 años': '(1 a 4)|(1-a-4-anos)|(1-4-anos)',
        'de 5 a 14 años': '(5 a 14)',
        'de 15 a 59 años': '(15 a 59)',
        'de 60 y más años': '(60 y más)|(60-y-mas)|(60-anos-y-mas)',
        'de 5 a 9 años': '(5 a 9)|(5-a-9-anos)|(5-9-anos)',
        'de 10 a 20 años': '(10 a 20)|(10-a-20-anos)',
        'de 21 a 59 años': '(21 a 59)|(21-a-59-anos)',
        'de 1 año': '(de-1-ano)',
        'menores a 2 años': '(< de 2)',
        'de 2 a 4 años': '(2 a 4)',
        'de 1 a 2 años': '(1-a-menor-de-2)',
        'de 2 a 5 años': '(2-a-menor-de-5)',
        'menores a 6 meses': '(menor-de-6-meses)',
        'de 6 meses a 1 año': '(6-meses-a-menor-de-1)|(6-m-a-menor-de-1-ano)',
        'de 10 a 14 años': '(10-14-anos)|(10-a-14-anos)',
        'de 15 a 19 años': '(15-19-anos)',
        'de 20 a 39 años': '(20-39-anos)',
        'de 40 a 49 años': '(40-49-anos)',
        'de 50 a 59 años': '(50-59-anos)',
        'de 6 meses': '(de-6-meses_)'
    },
    
    'especial': {
        'total': '(TOTAL)|(total)',
        'cantidad': '(Cantidad)',
        'embarazadas según IMC': '(imc_mujer-embarazada)',
        'población general según IMC': '(imc-1_)',
        'número de eventos': '(^Nro.$)|(Nro. Eventos$)',
        'número de afectados': '(^Nro. Afectados)|(Nro. Personas afectadas$)',
        'número de fallecidos': '(^Nro. Fallecidos)|(Nro. Personas fallecidas$)',
        
    }
}
    

def infer_category(text, patterns, lower=False):
    
    if lower:
        text = text.lower()
    
    category = None
    
    for k in patterns.keys():
        if len(re.findall(patterns[k], text)) > 0:
            category = k
    
    return category

def field_format(text):
    if text == None:
        return ''
    else:
        return text

# %%
## Contruyo una lista con todos los nombres de columnas en todos los sets de datos

indice = pd.read_csv('resources/indice.csv')
unicos = indice[['grvar', 'subvar', 'grupo', 'variable']].drop_duplicates(subset=['grvar', 'subvar', 'variable']).reset_index(drop=True)
unicos = unicos[unicos.variable.notna()]

schemas = []

for i, condicion in unicos.iterrows():
    
    for e, row in indice[(indice.grvar == condicion.grvar) & (indice.subvar == condicion.subvar) & (indice.variable == condicion.variable)].iterrows():
        schemas.append({**row, **{'columns': pd.read_csv('datos/' + row.filename).columns.tolist()}})
        
schemas = pd.DataFrame(schemas)

columnas = pd.Series(list(itertools.chain.from_iterable(schemas['columns'].drop_duplicates().tolist()))).drop_duplicates().tolist()

## Infiero atributos en estos nombres: si se refiere a hombres o mujeres, si describe casos que ocurren dentro o fuera de establecimientos de salud, qué rangos de edad representan y si indican alguna población en particular

column_classes = pd.DataFrame({c: {k: infer_category(c, patterns[k]) for k in patterns.keys()} for c in columnas[5:]}).T

## Compongo una descripción con estos atributos

column_descriptions = column_classes.apply(lambda row: ' '.join(' '.join([field_format(field) for field in row]).split()), axis=1).to_dict()

# %%
## Guardo una tabla con los atributos y un diccionario con descripciones

column_classes.to_csv('column_atributes.csv')

with open('resources/column_descriptions.json', 'w+') as f:
    json.dump(column_descriptions, f)

# %%
## Remplazo los nombres de columnas en cada documento producido

for fn in indice.filename.tolist():
    filename = 'datos/' + fn
    dfi = pd.read_csv(filename)
    dfi.columns = [column_descriptions[c] if c in column_descriptions.keys() else c for c in dfi.columns]
    dfi.to_csv(filename, index=False)

for fn in indice_agrupado.filename.tolist():
    filename = 'agrupados/' + fn
    dfi = pd.read_csv(filename)
    dfi.columns = [column_descriptions[c] if c in column_descriptions.keys() else c for c in dfi.columns]
    dfi.to_csv(filename, index=False)
